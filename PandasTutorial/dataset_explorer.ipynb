# %%
#import necessary libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading dataset, csv file
df = pd.read_csv("mvt.csv")
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#return dataframe by calling pandas instance
df
# Out:
#              ID            Date            LocationDescription  Arrest  \
# 0       8951354  12/31/12 23:15                         STREET   False
# 1       8951141  12/31/12 22:00                         STREET   False
# 2       8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3       8952223  12/31/12 22:00                         STREET   False
# 4       8951608  12/31/12 21:30                         STREET   False
# ...         ...             ...                            ...     ...
# 191636  1310068     1/1/01 0:05                         STREET   False
# 191637  1313404     1/1/01 0:01                         STREET   False
# 191638  1313442     1/1/01 0:01                         STREET   False
# 191639  1563324     1/1/01 0:01                         STREET   False
# 191640  1310463     1/1/01 0:01                         STREET   False
#
#         Domestic  Beat District CommunityArea  Year   Latitude  Longitude
# ...

# %%
#using `df.info()` to inform about your dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191641 entries, 0 to 191640
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   191641 non-null  int64
#  1   Date                 191641 non-null  object
#  2   LocationDescription  191641 non-null  object
#  3   Arrest               191641 non-null  bool
#  4   Domestic             191641 non-null  bool
#  5   Beat                 191641 non-null  int64
#  6   District             148589 non-null  object
#  7   CommunityArea        167038 non-null  object
#  8   Year                 191641 non-null  int64
#  9   Latitude             189365 non-null  float64
#  10  Longitude            189365 non-null  float64
# dtypes: bool(2), float64(2), int64(3), object(4)
# memory usage: 13.5+ MB

# %%
#df.head(x) return a sub-dataframe contain (int) x first rows in dataframe
df.head(70)
# Out:
#          ID            Date            LocationDescription  Arrest  Domestic  \
# 0   8951354  12/31/12 23:15                         STREET   False     False
# 1   8951141  12/31/12 22:00                         STREET   False     False
# 2   8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False     False
# 3   8952223  12/31/12 22:00                         STREET   False     False
# 4   8951608  12/31/12 21:30                         STREET   False     False
# ..      ...             ...                            ...     ...       ...
# 65  8949871   12/30/12 8:20                         STREET   False     False
# 66  8949314   12/30/12 8:20                         STREET   False     False
# 67  8949366   12/30/12 8:15                         STREET   False     False
# 68  8950022   12/30/12 8:00         VEHICLE NON-COMMERCIAL   False     False
# 69  8949844   12/30/12 7:15                         STREET    True     False
#
# ...

# %%
df.shape #return tuple where is shape of dataframe (x,y) x rows, y cols
# Out:
# (191641, 11)

# %%
#df.tail(x) return a sub-dataframe contain x-last rows of dataframe
df.tail(2)
# Out:
#              ID         Date LocationDescription  Arrest  Domestic  Beat  \
# 191639  1563324  1/1/01 0:01              STREET   False     False  1712
# 191640  1310463  1/1/01 0:01              STREET   False     False  1911
#
#        District CommunityArea  Year   Latitude  Longitude
# 191639      NaN           NaN  2001  41.971437 -87.727056
# 191640      NaN           NaN  2001  41.968327 -87.696388

# %%
#using pd.set_option(str-option, value-option) for set value option for str-option, example
pd.set_option('display.min_rows',15)
pd.set_option('display.max_rows', 100)

# %%
df
# Out:
#              ID            Date            LocationDescription  Arrest  \
# 0       8951354  12/31/12 23:15                         STREET   False
# 1       8951141  12/31/12 22:00                         STREET   False
# 2       8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3       8952223  12/31/12 22:00                         STREET   False
# 4       8951608  12/31/12 21:30                         STREET   False
# 5       8950793  12/31/12 20:30                         STREET    True
# 6       8950760  12/31/12 20:10                         STREET   False
# ...         ...             ...                            ...     ...
# 191634  1918610     1/1/01 0:05               RESIDENCE-GARAGE   False
# 191635  1310755     1/1/01 0:05               RESIDENCE-GARAGE   False
# 191636  1310068     1/1/01 0:05                         STREET   False
# 191637  1313404     1/1/01 0:01                         STREET   False
# ...

# %%
#using parathenses to slicing dataframe into series or more smaller instances
#example
example_first_series = df["Date"] #parameter is string which is name of the columns (series for more specific)
example_first_sub_dataframe_cut_by_slicing = df[["Date","ID"]] #parameter is list of names which are names of the columns (may be 1)
##########

# %%
example_first_series
# Out:
# 0         12/31/12 23:15
# 1         12/31/12 22:00
# 2         12/31/12 22:00
# 3         12/31/12 22:00
# 4         12/31/12 21:30
# 5         12/31/12 20:30
# 6         12/31/12 20:10
#                ...
# 191634       1/1/01 0:05
# 191635       1/1/01 0:05
# 191636       1/1/01 0:05
# 191637       1/1/01 0:01
# 191638       1/1/01 0:01
# 191639       1/1/01 0:01
# 191640       1/1/01 0:01
# Name: Date, Length: 191641, dtype: object

# %%
example_first_sub_dataframe_cut_by_slicing
# Out:
#                   Date       ID
# 0       12/31/12 23:15  8951354
# 1       12/31/12 22:00  8951141
# 2       12/31/12 22:00  8952745
# 3       12/31/12 22:00  8952223
# 4       12/31/12 21:30  8951608
# 5       12/31/12 20:30  8950793
# 6       12/31/12 20:10  8950760
# ...                ...      ...
# 191634     1/1/01 0:05  1918610
# 191635     1/1/01 0:05  1310755
# 191636     1/1/01 0:05  1310068
# 191637     1/1/01 0:01  1313404
# 191638     1/1/01 0:01  1313442
# 191639     1/1/01 0:01  1563324
# 191640     1/1/01 0:01  1310463
#
# [191641 rows x 2 columns]
